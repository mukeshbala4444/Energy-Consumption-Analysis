# %%
123
# Out:
# 123

# %%
import pandas as pd
import numpy as nup

# %%
data = pd.read_excel('/content/2021_final_bps_dataset.xlsx')

# %%
pd.set_option('display.max_columns', 500)

# %%
data.head()
# Out:
#       Sector     Subsector                            Organization  \
# 0  Municipal  Municipality  The Corporation of the City of Markham
# 1  Municipal  Municipality  The Corporation of the City of Markham
# 2  Municipal  Municipality  The Corporation of the City of Markham
# 3  Municipal  Municipality  The Corporation of the City of Markham
# 4  Municipal  Municipality  The Corporation of the City of Markham
#
#       Property Name Primary Property Type - Self Selected  \
# 0  Fire Station #91                          Fire Station
# 1  Fire Station #92                          Fire Station
# 2  Fire Station #93                          Fire Station
# 3  Fire Station #94                          Fire Station
# 4  Fire Station #95                          Fire Station
#
#    Portfolio Manager Property ID Portfolio Manager Parent Property ID  \
# 0                        3634451  Not Applicable: Standalone Property
# ...

# %%
data.tail()
# Out:
#               Sector      Subsector  \
# 15227  School Boards  School Boards
# 15228  School Boards  School Boards
# 15229  School Boards  School Boards
# 15230  School Boards  School Boards
# 15231  School Boards  School Boards
#
#                                             Organization  \
# 15227  Conseil scolaire de district catholique du Cen...
# 15228  Conseil scolaire de district catholique du Cen...
# 15229  Conseil scolaire de district catholique du Cen...
# 15230  Conseil scolaire de district catholique du Cen...
# 15231  Conseil scolaire de district catholique du Cen...
#
#                 Property Name Primary Property Type - Self Selected  \
# 15227  Saint-Joseph-d'Orléans                           K-12 School
# 15228              Saint-Rémi                           K-12 School
# 15229         Centre éducatif                                Office
# 15230           Samuel Genest                           K-12 School
# ...

# %%
data.shape

# %%
columns_to_drop = [
    'Fuel Oil #1 Use (GJ)',
    'Fuel Oil #2 Use (GJ)',
    'Fuel Oil #4 Use (GJ)',
    'Fuel Oil #5 & 6 Use (GJ)',
    'Diesel #2 Use (GJ)',
    'Kerosene Use (GJ)',
    'Propane Use (GJ)',
    'District Steam Use (GJ)',
    'District Hot Water Use (GJ)',
    'District Chilled Water Use (GJ)',
    'Wood Use (GJ)',
    'Custom Property ID 1 - Name',
    'Custom Property ID 1 - Value',
    'Custom Property ID 2 - Name',
    'Custom Property ID 2 - Value',
    'Custom Property ID 3 - Name',
    'Custom Property ID 3 - Name',
    'Drinking Water Treatment & Distribution - Average Flow (m³PD)',
    'Wastewater Treatment Plant - Average Influent Flow (m³PD)',
    'Address 2',
    'Data Quality Checker - Date Run'

]

data.drop(columns=columns_to_drop, inplace=True)

# %%
data.shape
# Out:
# (15232, 38)

# %%
data.head()
# Out:
#       Sector     Subsector                            Organization  \
# 0  Municipal  Municipality  The Corporation of the City of Markham
# 1  Municipal  Municipality  The Corporation of the City of Markham
# 2  Municipal  Municipality  The Corporation of the City of Markham
# 3  Municipal  Municipality  The Corporation of the City of Markham
# 4  Municipal  Municipality  The Corporation of the City of Markham
#
#       Property Name Primary Property Type - Self Selected  \
# 0  Fire Station #91                          Fire Station
# 1  Fire Station #92                          Fire Station
# 2  Fire Station #93                          Fire Station
# 3  Fire Station #94                          Fire Station
# 4  Fire Station #95                          Fire Station
#
#    Portfolio Manager Property ID Portfolio Manager Parent Property ID  \
# 0                        3634451  Not Applicable: Standalone Property
# ...

# %%
print('total rows :', data.shape[0])
print('total columns :', data.shape[1])
# Out:
# total rows : 15232
# total columns : 38

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15232 entries, 0 to 15231
# Data columns (total 38 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sector                                                      15232 non-null  object
#  1   Subsector                                                   15232 non-null  object
#  2   Organization                                                15232 non-null  object
#  3   Property Name                                               15232 non-null  object
#  4   Primary Property Type - Self Selected                       15232 non-null  object
#  5   Portfolio Manager Property ID                               15232 non-null  int64
#  6   Portfolio Manager Parent Property ID                        15232 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# Sector                                                        0
# Subsector                                                     0
# Organization                                                  0
# Property Name                                                 0
# Primary Property Type - Self Selected                         0
# Portfolio Manager Property ID                                 0
# Portfolio Manager Parent Property ID                          0
# Parent Property Name                                          0
# Year Ending                                                   0
# Address                                                       2
# City                                                          0
# Postal Code                                                   5
# Property GFA - Self-Reported (m²)                             0
# Number of Buildings                                           0
# Custom Property ID 3 - Value                                  0
# ...

# %%
data.dropna(subset=['Address'], inplace=True)
data.dropna(subset=['Postal Code'], inplace=True)

# %%
data.isnull().sum()
# Out:
# Sector                                                        0
# Subsector                                                     0
# Organization                                                  0
# Property Name                                                 0
# Primary Property Type - Self Selected                         0
# Portfolio Manager Property ID                                 0
# Portfolio Manager Parent Property ID                          0
# Parent Property Name                                          0
# Year Ending                                                   0
# Address                                                       0
# City                                                          0
# Postal Code                                                   0
# Property GFA - Self-Reported (m²)                             0
# Number of Buildings                                           0
# Custom Property ID 3 - Value                                  0
# ...
